# %%
# Q.1
# Price Data
item_dict = {'almonds': 6,
 'antioxidant juice': 9,
 'avocado': 1,
 'black tea': 4,
 'burgers': 4,
 'champagne': 3,
 'chicken': 4,
 'chocolate': 7,
 'chutney': 7,
 'cookies': 7,
 'cooking oil': 7,
 'cottage cheese': 9,
 'eggs': 9,
 'energy bar': 9,
 'energy drink': 3,
 'extra dark chocolate': 8,
 'french fries': 7,
 'fresh tuna': 9,
 'frozen smoothie': 7,
 'frozen vegetables': 2,
 'green grapes': 8,
 'green tea': 8,
 'honey': 9,
 'light cream': 5,
 'low fat yogurt': 4,
 'meatballs': 9,
 'milk': 5,
 'mineral water': 2,
 'oil': 9,
 'olive oil': 8,
 'pet food': 3,
 'protein bar': 1,
 'salad': 7,
 'salmon': 3,
 'shallot': 6,
 'shrimp': 2,
 'soup': 2,
 'spaghetti': 6,
 'spinach': 7,
 'tomato juice': 8,
 'tomatoes': 5,
 'turkey': 8,
 'vegetables mix': 3,
 'whole wheat flour': 5,
 'whole wheat pasta': 5,
 'whole wheat rice': 4,
 'yams': 7}

# transaction data
transaction_data = \
[['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole wheat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxidant juice', 'frozen smoothie', 'spinach', 'olive oil'],
['burgers', 'meatballs', 'eggs'],
['chutney'],
['turkey', 'avocado'],
['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
['low fat yogurt'],
['whole wheat pasta', 'french fries'],
['soup', 'light cream', 'shallot'],
['frozen vegetables', 'spaghetti', 'green tea'],
['french fries'],
['eggs', 'pet food'],
['cookies'],
['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
['spaghetti', 'champagne', 'cookies'],
['mineral water', 'salmon'],
['mineral water'],
['shrimp', 'chocolate', 'chicken', 'honey', 'oil', 'cooking oil', 'low fat yogurt'],
['turkey', 'eggs'],
['turkey', 'fresh tuna', 'tomatoes', 'spaghetti', 'mineral water', 'black tea', 'salmon', 'eggs', 'chicken', 'extra dark chocolate'],
['meatballs', 'milk', 'honey', 'french fries', 'protein bar']]


# Task 1
# Find how many unique items are present in the data?  
# (Hint: It will correspond to the number of key pairs in the Cost dictionary)
the_set = set(item_dict.keys())
# print ('Unique items: ', the_set)

# Task 2
# Find the total number of transactions?
print('Total number of transations: ', len(transaction_data))
print()

# Task 3
# Add items, try adding the item “banana” in stores. The cost of this item is $5.
# Add the item “banana” to the Cost dictionary. 

item_dict['banana'] = 5
print('Added banana.\nNew item_dict: \n', item_dict)
print()

# Task 4
# Use a function named add_item( ) to automatically add an item to the Cost dictionary given its name and price.
def add_item(dicts, name, price):
    dicts[name] = price
    return dicts

print('Added leaf item.\nNew item_dict: \n', add_item(item_dict, 'tea leaf', 2))
print()

# Task 5
# Create a function called remove_item( ) to automatically remove an item from the Cost dictionary given its name.
def remove_item(dicts, name):
    dicts.pop(name)
    return dicts

print('Added yams item.\nNew item_dict: \n', remove_item(item_dict, 'yams'))
# Out:
# Total number of transations:  20
#
# Added banana.
# New item_dict:
#  {'almonds': 6, 'antioxidant juice': 9, 'avocado': 1, 'black tea': 4, 'burgers': 4, 'champagne': 3, 'chicken': 4, 'chocolate': 7, 'chutney': 7, 'cookies': 7, 'cooking oil': 7, 'cottage cheese': 9, 'eggs': 9, 'energy bar': 9, 'energy drink': 3, 'extra dark chocolate': 8, 'french fries': 7, 'fresh tuna': 9, 'frozen smoothie': 7, 'frozen vegetables': 2, 'green grapes': 8, 'green tea': 8, 'honey': 9, 'light cream': 5, 'low fat yogurt': 4, 'meatballs': 9, 'milk': 5, 'mineral water': 2, 'oil': 9, 'olive oil': 8, 'pet food': 3, 'protein bar': 1, 'salad': 7, 'salmon': 3, 'shallot': 6, 'shrimp': 2, 'soup': 2, 'spaghetti': 6, 'spinach': 7, 'tomato juice': 8, 'tomatoes': 5, 'turkey': 8, 'vegetables mix': 3, 'whole wheat flour': 5, 'whole wheat pasta': 5, 'whole wheat rice': 4, 'yams': 7, 'banana': 5}
#
# Added leaf item.
# New item_dict:
# ...

# %%
# Q.2

# Price Data
item_dict = {'almonds': 6,
 'antioxidant juice': 9,
 'avocado': 1,
 'black tea': 4,
 'burgers': 4,
 'champagne': 3,
 'chicken': 4,
 'chocolate': 7,
 'chutney': 7,
 'cookies': 7,
 'cooking oil': 7,
 'cottage cheese': 9,
 'eggs': 9,
 'energy bar': 9,
 'energy drink': 3,
 'extra dark chocolate': 8,
 'french fries': 7,
 'fresh tuna': 9,
 'frozen smoothie': 7,
 'frozen vegetables': 2,
 'green grapes': 8,
 'green tea': 8,
 'honey': 9,
 'light cream': 5,
 'low fat yogurt': 4,
 'meatballs': 9,
 'milk': 5,
 'mineral water': 2,
 'oil': 9,
 'olive oil': 8,
 'pet food': 3,
 'protein bar': 1,
 'salad': 7,
 'salmon': 3,
 'shallot': 6,
 'shrimp': 2,
 'soup': 2,
 'spaghetti': 6,
 'spinach': 7,
 'tomato juice': 8,
 'tomatoes': 5,
 'turkey': 8,
 'vegetables mix': 3,
 'whole wheat flour': 5,
 'whole wheat pasta': 5,
 'whole wheat rice': 4,
 'yams': 7}

# transaction data
transaction_data = \
[['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole wheat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxidant juice', 'frozen smoothie', 'spinach', 'olive oil'],
['burgers', 'meatballs', 'eggs'],
['chutney'],
['turkey', 'avocado'],
['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
['low fat yogurt'],
['whole wheat pasta', 'french fries'],
['soup', 'light cream', 'shallot'],
['frozen vegetables', 'spaghetti', 'green tea'],
['french fries'],
['eggs', 'pet food'],
['cookies'],
['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
['spaghetti', 'champagne', 'cookies'],
['mineral water', 'salmon'],
['mineral water'],
['shrimp', 'chocolate', 'chicken', 'honey', 'oil', 'cooking oil', 'low fat yogurt'],
['turkey', 'eggs'],
['turkey', 'fresh tuna', 'tomatoes', 'spaghetti', 'mineral water', 'black tea', 'salmon', 'eggs', 'chicken', 'extra dark chocolate'],
['meatballs', 'milk', 'honey', 'french fries', 'protein bar']]

# Function to find the price of a particular item 
def find_price(item_name):
    
    # Try except block to handle error if item was not found
    try:
        price = item_dict[item_name]
        return price
    except:
        return "Item not found"

# Find the transaction_data by transaction_no 
def find_transaction_data(transaction_no):
    items = transaction_data [transaction_no-1]
    return items
        
# Find the number of items in a particular transaction 
def no_of_items(transaction_no):
    items = find_transaction_data(transaction_no)
    print("\nTotal number of items are : ",len(items))
    
# Function to find the cost of items of a particular transaction 
def find_cost_items(transaction):
    amount = 0
    # using for loop, sum up the price of all items  
    for i in transaction:
        amount += item_dict[i] 
    return amount 
    
# calculate the tax on a particular amount 
def calculate_tax(amount):
    tax = (5 * amount)/100 
    return tax 
    
# Find the total amount after after adding tax
def find_total(transaction):
    amount = find_cost_items (transaction)
    tax = calculate_tax(amount)
    total = amount + tax 
    return total 
    
# Task -1  (find price of salmon)
price = find_price("salmon")
print("\nPrice : $",price)

# Task -2 (find the ninth transaction)
items = find_transaction_data(9)
print("\nThe items are : ", *items)
    
# Task -3 (find number of items)
no_of_items(9)

# Task -4 (Find cost of ninth transaction)
items = find_transaction_data(9)
cost = find_cost_items (items)
print("\nThe cost of items is $",cost)

# Task -5 (Find final price of second transaction after taxes)
items = find_transaction_data(2)
total = find_total(items)
print("\nFinal price after taxes: $",total)
# Out:
# Price : $ 3
#
# The items are :  frozen vegetables spaghetti green tea
#
# Total number of items are :  3
#
# The cost of items is $ 16
#
# Final price after taxes: $ 23.1

# %%
# Q3.
# transaction data
transaction_data = [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole wheat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxidant juice', 'frozen smoothie', 'spinach', 'olive oil'],
['burgers', 'meatballs', 'eggs'],
['chutney'],
['turkey', 'avocado'],
['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
['low fat yogurt'],
['whole wheat pasta', 'french fries'],
['soup', 'light cream', 'shallot'],
['frozen vegetables', 'spaghetti', 'green tea'],
['french fries'],
['eggs', 'pet food'],
['cookies'],
['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
['spaghetti', 'champagne', 'cookies'],
['mineral water', 'salmon'],
['mineral water'],
['shrimp', 'chocolate', 'chicken', 'honey', 'oil', 'cooking oil', 'low fat yogurt'],
['turkey', 'eggs'],
['turkey', 'fresh tuna', 'tomatoes', 'spaghetti', 'mineral water', 'black tea', 'salmon', 'eggs', 'chicken', 'extra dark chocolate'],
['meatballs', 'milk', 'honey', 'french fries', 'protein bar']]

frequency_dict ={}

for transaction in transaction_data: #looping over each transaction

    for item in transaction: #looping over each item
        if item in frequency_dict.keys():
            frequency_dict[item] += 1 # add 1 to count if item already exist
        else:
            frequency_dict[item] = 1 #create a new key if  is found for first time

def update_counter(transaction,frequency_dict):
    for item in transaction: #looping over each item
        if item in frequency_dict.keys():
            frequency_dict[item] +=1 # add 1 to count if item already exist
        else:
            frequency_dict[item] = 1 #create a new key if  is found for first time

          
update_counter(["honey","pet food","shrimp"], frequency_dict)

print('Frequency dict: \n', frequency_dict)
# Out:
# Frequency dict:
#  {'shrimp': 3, 'almonds': 1, 'avocado': 2, 'vegetables mix': 1, 'green grapes': 1, 'whole wheat flour': 1, 'yams': 1, 'cottage cheese': 1, 'energy drink': 1, 'tomato juice': 1, 'low fat yogurt': 3, 'green tea': 3, 'honey': 4, 'salad': 1, 'mineral water': 6, 'salmon': 3, 'antioxidant juice': 1, 'frozen smoothie': 1, 'spinach': 1, 'olive oil': 1, 'burgers': 2, 'meatballs': 2, 'eggs': 5, 'chutney': 1, 'turkey': 4, 'milk': 2, 'energy bar': 1, 'whole wheat rice': 1, 'whole wheat pasta': 1, 'french fries': 3, 'soup': 1, 'light cream': 1, 'shallot': 1, 'frozen vegetables': 1, 'spaghetti': 3, 'pet food': 2, 'cookies': 2, 'cooking oil': 2, 'champagne': 1, 'chocolate': 1, 'chicken': 2, 'oil': 1, 'fresh tuna': 1, 'tomatoes': 1, 'black tea': 1, 'extra dark chocolate': 1, 'protein bar': 1}

# %%
# Q.4
import operator
import time

transaction_data = [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole wheat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxidant juice', 'frozen smoothie', 'spinach', 'olive oil'],
['burgers', 'meatballs', 'eggs'],
['chutney'],
['turkey', 'avocado'],
['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
['low fat yogurt'],
['whole wheat pasta', 'french fries'],
['soup', 'light cream', 'shallot'],
['frozen vegetables', 'spaghetti', 'green tea'],
['french fries'],
['eggs', 'pet food'],
['cookies'],
['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
['spaghetti', 'champagne', 'cookies'],
['mineral water', 'salmon'],
['mineral water'],
['shrimp', 'chocolate', 'chicken', 'honey', 'oil', 'cooking oil', 'low fat yogurt'],
['turkey', 'eggs'],
['turkey', 'fresh tuna', 'tomatoes', 'spaghetti', 'mineral water', 'black tea', 'salmon', 'eggs', 'chicken', 'extra dark chocolate'],
['meatballs', 'milk', 'honey', 'french fries', 'protein bar']]

frequency_dict = {}

for transaction in transaction_data: #looping over each transaction
    for item in transaction: #looping over each item
        if item in frequency_dict.keys():
            frequency_dict[item] +=1 # add 1 to count if item already exist
        else:
            frequency_dict[item] = 1 #create a new key if is found for first time

def update_counter(transaction,frequency_dict):
    for item in transaction: #looping over each item
        if item in frequency_dict.keys():
            frequency_dict[item] += 1 # add 1 to count if item already exist
        else:
            frequency_dict[item] = 1 #create a new key if is found for first time

update_counter(["honey","pet food","shrimp"], frequency_dict)

# print('frequency_dict: ', frequency_dict)

# Task 1 - What is the top-selling item?
dict = frequency_dict
dict_sort = sorted(dict.items(), key=operator.itemgetter(1),reverse=True)
# print(dict_sort)
print('top-selling item: ', dict_sort[0])
print()

# Task 2 - Sort the frequency_ dict
# Merge sort
def merge_sort(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
    # create temp arrays
    L = [0] * (n1)
    R = [0] * (n2)
    # Copy data to temp arrays L[] and R[]
    for i in range(0, n1):
        L[i] = arr[l + i]
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
    # Merge the temp arrays back into arr[l..r]
    i = 0     # Initial index of first subarray
    j = 0     # Initial index of second subarray
    k = l     # Initial index of merged subarray
    while i < n1 and j < n2:
        if L[i][1] <= R[j][1]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    # Copy the remaining elements of L[], if there
    # are any
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
    # Copy the remaining elements of R[], if there
    # are any
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1

merge_sort_list = list(frequency_dict.items())

start = time.time()
merge(merge_sort_list, 0, len(merge_sort_list)//2, len(merge_sort_list) - 1)
end = time.time()
merge_sort_elapsed_time = end - start;


# Insertion sort
def insertion_sort(arr):
    # Traverse through 1 to len(arr)
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key[1] < arr[j][1] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key

insertion_sort_list = list(frequency_dict.items())

start = time.time()
insertion_sort(insertion_sort_list)
end = time.time()
insertion_sort_elapsed_time = end - start;
# print('insertion_sort list:', insertion_sort_list)
       

# Selection sort
def selection_sort(my_list):
    for i in range(len(my_list) - 1):
        min_ind = i
        for j in range(i + 1, len(my_list)):
            if my_list[j][1] < my_list[min_ind][1]:
                min_ind = j
        my_list[i], my_list[min_ind] = my_list[min_ind], my_list[i]

selection_sort_list = list(frequency_dict.items())

start = time.time()
selection_sort(selection_sort_list)
end = time.time()
selection_sort_elapsed_time = end - start;
# print('selection_sort_list list:', selection_sort_list)

# Task 3 - Rank the sorting algorithms in order of the time they take to sort items.
print()
print('Rank the sorting algorithms in order of the time they take to sort items (need to execute several times):')
print('Merge sort elapsed time: ', merge_sort_elapsed_time * 1000, ' ms')
print('Insertion sort elapsed time: ', insertion_sort_elapsed_time * 1000, ' ms')
print('Selection sort: elapsed time:', selection_sort_elapsed_time * 1000, ' ms')
# Out:
# top-selling item:  ('mineral water', 6)
#
#
# Rank the sorting algorithms in order of the time they take to sort items (need to execute several times):
# Merge sort elapsed time:  0.0  ms
# Insertion sort elapsed time:  0.0  ms
# Selection sort: elapsed time: 0.0  ms
